# %% [markdown]
# # Demo: Two-type CCP–NPL with EM

# %%
# %pip -q install numpy pandas scipy
from estimate_npl_em import estimate_npl_em
CSV = "/mnt/data/toy_panel_with_random_x copy.csv"
out = estimate_npl_em(CSV, outdir="/mnt/data/nfxp_finlit/outputs_npl_em",
                      n_a=24, gh_order=5, em_iters=4, nm_steps=20)
out
